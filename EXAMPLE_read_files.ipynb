# %%
import pandas as pd

# %%
# !pip install pyarrow
# Out:
# ...
#      |████████████████████████████████| 20.7 MB 9.6 MB/s eta 0:00:01
# ...

# %% [markdown]
# ## Read Parquet File
# Requires pyarrow to be installed
# `pip install pyarrow`

# %%
df = pd.read_parquet('cicids2017/clean/all_malicious.parquet')
df.head()
# Out:
#    Destination Port  Protocol           Timestamp  Flow Duration  \
# 0              80.0       6.0 2017-07-07 13:05:00           52.0
# 1              80.0       6.0 2017-07-07 13:05:00      5386396.0
# 2              80.0       6.0 2017-07-07 13:05:00      5024211.0
# 3              80.0       6.0 2017-07-07 13:05:00           70.0
# 4              80.0       6.0 2017-07-07 13:05:00      5021059.0
#
#    Total Fwd Packets  Total Backward Packets  Fwd Packets Length Total  \
# 0                1.0                     1.0                       0.0
# 1                3.0                     1.0                       0.0
# 2                6.0                     5.0                     703.0
# 3                1.0                     1.0                       0.0
# 4                6.0                     5.0                     703.0
#
#    Bwd Packets Length Total  Fwd Packet Length Max  Fwd Packet Length Min  \
# ...

# %%
df.shape
# Out:
# (425619, 70)

# %% [markdown]
# ## Read Feather File

# %%
df = pd.read_feather('cicids2017/clean/all_malicious.feather')
df.head()
# Out:
#    Destination Port  Protocol           Timestamp  Flow Duration  \
# 0              80.0       6.0 2017-07-07 15:56:00       604986.0
# 1              80.0       6.0 2017-07-07 15:56:00       604688.0
# 2              80.0       6.0 2017-07-07 15:56:00       604747.0
# 3              80.0       6.0 2017-07-07 15:56:00       651053.0
# 4              80.0       6.0 2017-07-07 15:56:00       651042.0
#
#    Total Fwd Packets  Total Backward Packets  Fwd Packets Length Total  \
# 0                3.0                     4.0                      26.0
# 1                3.0                     5.0                      26.0
# 2                3.0                     5.0                      26.0
# 3                3.0                     5.0                      26.0
# 4                3.0                     4.0                      26.0
#
#    Bwd Packets Length Total  Fwd Packet Length Max  Fwd Packet Length Min  \
# ...

# %%
df.shape
# Out:
# (425619, 70)
